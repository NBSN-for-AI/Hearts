# %% [markdown]
# ### data

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
loss = pd.read_csv('loss.csv')
plt.plot(loss)
plt.show()

# %%
score = pd.read_csv('score.csv')
plt.plot(loss)
plt.show()
