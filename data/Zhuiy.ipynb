# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
log = pd.read_csv('Zhuiy_rl_log.csv')
plt.plot(log)

# %%
meanlog = pd.read_csv('Zhuiy_rl_meanlog.csv')
plt.plot(meanlog)

# %%
lossing = pd.read_csv('Zhuiy_rl_loss.csv')
plt.plot(lossing)
